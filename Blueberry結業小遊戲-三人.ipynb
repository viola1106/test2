# %%
import requests
import json

token = "EAAKP6m7lRsYBAMZAJ349UtH0jZA6Tn4dVihFXuz9jC4lXVhmtnHdeFBLpuhp5YJTDP5kZCwJh6Xtb2MZCA2XVZCIVLKY0ZCncmuRfOrH74k7uaCRKM6PQk4LZCgWIUwnWonEOaVFsFqy2Ytfk46eZBZCJMRJm4TftRJfZCRhFjAXGxxfOK49yZAOqvu1Dbmy5DBxLzUJfVx3ZCttobGS9rMJKsuoy8FOmgaWjSEZD"
blueberry_id="116833604352865"

# 粉專的連結-讀取
res = requests.get("https://graph.facebook.com/v13.0/"+blueberry_id+"/posts?access_token="+token)
jd=json.loads(res.text)

def game_start():
    # 遊戲開始貼文底下的回覆
    start_id=jd["data"][-1]["id"]  #遊戲開始貼文id
    start_res = requests.get("https://graph.facebook.com/v13.0/"+"116833604352865_116842771018615"+"/comments?access_token="+token)
    start_jd=json.loads(start_res.text)
    if start_jd["data"]==[]:
            return game_start()
    else:
        # 是否開始玩遊戲:判斷comments的內容關鍵字
        level_start_comments = start_jd["data"][0]["message"]   #遊戲留言
        level_start_comments = level_start_comments.split("+")
        if "start" in level_start_comments or "Start" in level_start_comments:  #如果留言:start
            start_comments_id = start_jd["data"][0]["id"] #留言id
            comments_id.append(start_comments_id)
            #回覆貼文網址:選擇角色
            content = "請選擇角色 ➥https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116842904351935%26id%3D116833604352865"
            level_char_link = requests.post("https://graph.facebook.com/v13.0/"+start_comments_id+"/comments?message="+content+"&access_token="+token)
            player_num = int(level_start_comments[1])
    return player_num    
def level_char():  #選擇角色
    level_char_id = jd["data"][-2]["id"]
    char_res = requests.get("https://graph.facebook.com/v13.0/"+level_char_id+"/comments?access_token="+token)
    char_jd=json.loads(char_res.text)
    player_name=[]  #儲存玩家選擇角色
    if char_jd["data"] == []:  #判斷有無留言
        return level_char()
    elif len(char_jd["data"]) != player_num:  #判斷留言數，不等於人數就繼續迴圈
        return level_char()
    else:     #判斷留言:選擇角色
        for num in range(player_num):  #每個留言都判斷角色名稱
            level_char_name = char_jd["data"][num]["message"]
            if  "一號角色" in level_char_name or "派森" in level_char_name:
                level_char_id = char_jd["data"][num]["id"]
                comments_id.append(level_char_id)
                content = "進入Level_1 ➥https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116843197685239%26id%3D116833604352865"
                level1_link = requests.post("https://graph.facebook.com/v13.0/"+level_char_id+"/comments?message="+content+"&access_token="+token)
                player_name.append("派森")  #儲存玩家選擇角色
            elif "二號角色" in level_char_name or "百科" in level_char_name:
                level_char_id = char_jd["data"][num]["id"]
                comments_id.append(level_char_id)
                content = "進入Level_1 ➥https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116843197685239%26id%3D116833604352865"
                level1_link = requests.post("https://graph.facebook.com/v13.0/"+level_char_id+"/comments?message="+content+"&access_token="+token)
                player_name.append("百科")
            elif "三號角色" in level_char_name or "伊瑟爾" in level_char_name:
                level_char_id = char_jd["data"][num]["id"]
                comments_id.append(level_char_id)
                content = "進入Level_1 ➥https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116843197685239%26id%3D116833604352865"
                level1_link = requests.post("https://graph.facebook.com/v13.0/"+level_char_id+"/comments?message="+content+"&access_token="+token)
                player_name.append("伊瑟爾")
    return player_name
            
def level1():
     #第一關:(正解:5個)
    level1_id = jd["data"][-3]["id"]
    level1_res = requests.get("https://graph.facebook.com/v13.0/"+level1_id+"/comments?access_token="+token)
    level1_jd=json.loads(level1_res.text)
    if level1_jd["data"] == []:  #確認有無留言
        return level1()  #沒有的話繼續執行確認
    elif len(level1_jd["data"]) != player_num:  #判斷留言數，不等於人數就繼續迴圈
        return level1()  
    else:
        for num in range(player_num):
            level1_comments=level1_jd["data"][num]["message"] #留言內容
            level1_comments_id = level1_jd["data"][num]["id"]
            comments_id.append(level1_comments_id)
            level1_comments=level1_comments.split("+")
            if name in level1_comments:           
                if "5個" in level1_comments or "5" in level1_comments or "五" in level1_comments:
                    score1=5
                    content = "Level_2 ➥https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116843751018517%26id%3D116833604352865"
                    level2_link = requests.post("https://graph.facebook.com/v13.0/"+level1_comments_id+"/comments?message="+content+"&access_token="+token)
                elif "4個" in level1_comments or "4" in level1_comments or "四" in level1_comments:
                    score1=4
                    content = "Level_2 ➥https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116843751018517%26id%3D116833604352865"
                    level2_link = requests.post("https://graph.facebook.com/v13.0/"+level1_comments_id+"/comments?message="+content+"&access_token="+token)
                elif "3個" in level1_comments or "3" in level1_comments or "三" in level1_comments:
                    score1=3
                    content = "Level_2 ➥https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116843751018517%26id%3D116833604352865"
                    level2_link = requests.post("https://graph.facebook.com/v13.0/"+level1_comments_id+"/comments?message="+content+"&access_token="+token)
                elif "2個" in level1_comments or "2" in level1_comments or "二" in level1_comments:
                    score1=2
                    content = "Level_2 ➥https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116843751018517%26id%3D116833604352865"
                    level2_link = requests.post("https://graph.facebook.com/v13.0/"+level1_comments_id+"/comments?message="+content+"&access_token="+token)
                elif "1個" in level1_comments or "1" in level1_comments or "一" in level1_comments:
                    score1=1
                    content = "Level_2 ➥https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116843751018517%26id%3D116833604352865"
                    level2_link = requests.post("https://graph.facebook.com/v13.0/"+level1_comments_id+"/comments?message="+content+"&access_token="+token)
                else:
                    score1=0
                    content = "Level_2 ➥https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116843751018517%26id%3D116833604352865"
                    level2_link = requests.post("https://graph.facebook.com/v13.0/"+level1_comments_id+"/comments?message="+content+"&access_token="+token)
    return score1

def level2():
    #第二關(正解:A)
    level2_id = jd["data"][-4]["id"] #第二關id
    level2_res = requests.get("https://graph.facebook.com/v13.0/"+level2_id+"/comments?access_token="+token)
    level2_jd=json.loads(level2_res.text)
    if level2_jd["data"] == []:  #確認有無留言
        return level2()        #沒有的話繼續執行確認  
    elif len(level2_jd["data"]) != player_num:  #判斷留言數，不等於人數就繼續迴圈
        return level2()        
    else:
        for num in range(player_num):
            level2_comments=level2_jd["data"][num]["message"] #第一個留言內容
            level2_comments_id = level2_jd["data"][num]["id"] #第一個留言id
            comments_id.append(level2_comments_id)
            if name in level2_comments:
                if "A" in level2_comments or "a" in level2_comments:  #正解:A
                    score2=2   #答對+2分，回覆貼文網址:level4
                    content = "答對了!! Go to Level_4 ➥https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116843977685161%26id%3D116833604352865"
                    level4_link = requests.post("https://graph.facebook.com/v13.0/"+level2_comments_id+"/comments?message="+content+"&access_token="+token)
                elif "B" in level2_comments or "C" in level2_comments or "b" in level2_comments or "c" in level2_comments:
                    score2=0   #答錯0分，回覆貼文網址:level3
                    content = "噗!答錯了! Level_3 ➥https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116843814351844%26id%3D116833604352865"
                    level3_link = requests.post("https://graph.facebook.com/v13.0/"+level2_comments_id+"/comments?message="+content+"&access_token="+token)
                else:
                    content = "答非所問! Level_3 ➥https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116843814351844%26id%3D116833604352865"
                    level3_link = requests.post("https://graph.facebook.com/v13.0/"+level2_comments_id+"/comments?message="+content+"&access_token="+token)
    return score2

def level3():
    #第三關(正解:ans_count==3)
    level3_id = jd["data"][-5]["id"] #第三關id
    level3_res = requests.get("https://graph.facebook.com/v13.0/"+level3_id+"/comments?access_token="+token)
    level3_jd=json.loads(level3_res.text)
    if level3_jd["data"]==[]: #確認有無留言
        return level3() #沒有的話繼續執行確認
    elif len(level3_jd["data"]) != player_num:  #判斷留言數，不等於人數就繼續迴圈
        return level3() 
    else:
        for num in range(player_num):
            level3_comments=level3_jd["data"][num]["message"] #第一個留言內容
            level3_comments_id = level3_jd["data"][num]["id"] #第一個留言id
            comments_id.append(level3_comments_id)
            correct=["pandas","numpy","datetime","time","BeautifulSoup","selenium","pymongo",
                    "pymysql","cv2","tkinter","random","requests","bs4"]  #正確答案
            level3_comments=level3_comments.split("+")  #回答留言是字串，先用","切割後判斷是否正確
            ans_count=0  #計算回答正確的答案有幾個
            for ans in level3_comments:
                if ans in correct:
                    ans_count+=1
            if ans_count==3:  #如果正確答案數==3:正解
                #回覆貼文網址:level4
                score3=2
                content = "全對!喔耶~ Level_4 ➥https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116843977685161%26id%3D116833604352865"
                level4_link = requests.post("https://graph.facebook.com/v13.0/"+level3_comments_id+"/comments?message="+content+"&access_token="+token)
            else:
                #回覆貼文網址:level4
                content = "有錯!這樣不行喔~ Level_4 ➥https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116843977685161%26id%3D116833604352865"
                level4_link = requests.post("https://graph.facebook.com/v13.0/"+level3_comments_id+"/comments?message="+content+"&access_token="+token)
    return score3

def level4():
    #第四關(正解:A)
    level4_id = jd["data"][-6]["id"] #第四關id
    level4_res = requests.get("https://graph.facebook.com/v13.0/"+level4_id+"/comments?access_token="+token)
    level4_jd=json.loads(level4_res.text)
    if level4_jd["data"]==[]:
        return level4()
    elif len(level4_jd["data"]) != player_num:
        return level4() 
    else:
        for num in range(player_num):
            level4_comments=level4_jd["data"][num]["message"] #第一個留言內容
            level4_comments_id = level4_jd["data"][num]["id"] #第一個留言id
            comments_id.append(level4_comments_id)
            if "A" in level4_comments or "a" in level4_comments:
                score4=2
                content = "答對了!! Level_5 ➥https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116844161018476%26id%3D116833604352865"
                level5_link = requests.post("https://graph.facebook.com/v13.0/"+level4_comments_id+"/comments?message="+content+"&access_token="+token)
            elif "B" in level4_comments or "b" in level4_comments or "C" in level4_comments or "c" in level4_comments:
                score4=0
                content = "答錯啦~ Level_5 ➥https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116844161018476%26id%3D116833604352865"
                level5_link = requests.post("https://graph.facebook.com/v13.0/"+level4_comments_id+"/comments?message="+content+"&access_token="+token)
            else: #回答非選項
                roung_ans = requests.post("https://graph.facebook.com/v13.0/"+level4_comments_id+"/comments?message=回答錯誤，拜拜~&access_token="+token)
    return score4

def level5():
    #第五關(正解:B)
    level5_id = jd["data"][-7]["id"] #第五關id
    level5_res = requests.get("https://graph.facebook.com/v13.0/"+level5_id+"/comments?access_token="+token)
    level5_jd=json.loads(level5_res.text)
    if level5_jd["data"]==[]:
        return level5()
    else:
        level5_comments=level5_jd["data"][0]["message"] #第一個留言內容
        level5_comments_id = level5_jd["data"][0]["id"] #第一個留言id
        comments_id.append(level5_comments_id)
        if "B" in level5_comments or "b" in level5_comments:  #正解!
            score+=2
            #回覆貼文網址:level6
            content = "答對了!! Level_6 ➥https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116844224351803%26id%3D116833604352865"
            level5_link = requests.post("https://graph.facebook.com/v13.0/"+level5_comments_id+"/comments?message="+content+"&access_token="+token)
        elif "A" in level5_comments or "C" in level5_comments or "a" in level5_comments or "c" in level5_comments:
            score+=0
            #回覆貼文網址:level6
            content = "答錯啦~ Level_6 ➥https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116844224351803%26id%3D116833604352865"
            level5_link = requests.post("https://graph.facebook.com/v13.0/"+level5_comments_id+"/comments?message="+content+"&access_token="+token)
    return score

def level6(score):
    #第六關(正解:C)
    level6_id = jd["data"][-8]["id"] #第六關id
    level6_res = requests.get("https://graph.facebook.com/v13.0/"+level6_id+"/comments?access_token="+token)
    level6_jd=json.loads(level6_res.text)
    if level6_jd["data"]==[]:
        return level6(score)
    else:
        level6_comments=level6_jd["data"][0]["message"] #第一個留言內容
        level6_comments_id = level6_jd["data"][0]["id"] #第一個留言id
        comments_id.append(level6_comments_id)
        if "C" in level6_comments or "c" in level6_comments:
            score+=2
            #回覆貼文網址:level7
            content = "答對了!太棒了! Level_7 ➥https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116844317685127%26id%3D116833604352865"
            level7_link = requests.post("https://graph.facebook.com/v13.0/"+level6_comments_id+"/comments?message="+content+"&access_token="+token)
        elif "A" in level6_comments or "B" in level6_comments or "a" in level6_comments or "b" in level6_comments:
            score+=0
            #回覆貼文網址:level7
            content = "錯!用Pyhon啊~ Level_7 ➥https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116844317685127%26id%3D116833604352865"
            level7_link = requests.post("https://graph.facebook.com/v13.0/"+level6_comments_id+"/comments?message="+content+"&access_token="+token)
        else:
            content = "亂寫!! Level_7 ➥https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116844317685127%26id%3D116833604352865"
            level7_link = requests.post("https://graph.facebook.com/v13.0/"+level6_comments_id+"/comments?message="+content+"&access_token="+token)
    return score

def level7(score):
    #第七關(交給命運: 結業Y/N)
    level7_id = jd["data"][-9]["id"] #第七關id(結果)
    level7_res = requests.get("https://graph.facebook.com/v13.0/"+level7_id+"/comments?access_token="+token)
    level7_jd=json.loads(level7_res.text)
    if level7_jd["data"]==[]:
        return level7(score)
    else:
        level7_comments=level7_jd["data"][0]["message"] #第一個留言內容
        level7_comments_id = level7_jd["data"][0]["id"] #第一個留言id
        comments_id.append(level7_comments_id)
        if "派森" in level7_comments: ##判斷level6有沒有答對
            if "C" in level6_comments or "c" in level6_comments: #答對直接計算分數
                if score < 10:
                    #回覆貼文網址:lose
                    content = "message=總分:"+str(score)+"再來一次?  https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116845121018380%26id%3D116833604352865"
                    lose_link = requests.post("https://graph.facebook.com/v13.0/"+level7_comments_id+"/comments?"+content+"&attachment_url=https://i.ibb.co/CzqFsLW/python-lose.jpg&access_token="+token)
                else:
                    #回覆貼文網址:WIN
                    content = "message=總分:"+str(score)+"WIN!!!!"+"再來一次?  https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116845121018380%26id%3D116833604352865"
                    win_link = requests.post("https://graph.facebook.com/v13.0/"+level7_comments_id+"/comments?"+content+"&attachment_url=https://i.ibb.co/86j3wvD/win.jpg&access_token="+token)
            else: #答錯補成答對的分數
                score+=2
                if score < 10:
                    #回覆貼文網址:lose
                    content = "message=總分:"+str(score)+"再來一次?  https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116845121018380%26id%3D116833604352865"
                    lose_link = requests.post("https://graph.facebook.com/v13.0/"+level7_comments_id+"/comments?"+content+"&attachment_url=https://i.ibb.co/CzqFsLW/python-lose.jpg&access_token="+token)
                else:
                    #回覆貼文網址:WIN
                    content = "message=總分:"+str(score)+"WIN!!!!"+"再來一次?  https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116845121018380%26id%3D116833604352865"
                    win_link = requests.post("https://graph.facebook.com/v13.0/"+level7_comments_id+"/comments?"+content+"&attachment_url=https://i.ibb.co/86j3wvD/win.jpg&access_token="+token)
        elif "百科" in level7_comments: ##判斷level5有沒有答對
            if "B" in level5_comments or "b" in level5_comments: #答對直接計算分數
                if score < 10:
                    #回覆貼文網址:lose
                    content = "message=總分:"+str(score)+"再來一次?  https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116845121018380%26id%3D116833604352865"
                    lose_link = requests.post("https://graph.facebook.com/v13.0/"+level7_comments_id+"/comments?"+content+"&attachment_url=https://i.ibb.co/Ph04ym0/bike-lose.jpg&access_token="+token)
                else:
                    #回覆貼文網址:WIN
                    content = "message=總分:"+str(score)+"WIN!!!!"+"再來一次?  https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116845121018380%26id%3D116833604352865"
                    win_link = requests.post("https://graph.facebook.com/v13.0/"+level7_comments_id+"/comments?"+content+"&attachment_url=https://i.ibb.co/86j3wvD/win.jpg&access_token="+token)
            else: #答錯補成答對的分數
                score+=2
                if score < 10:
                    #回覆貼文網址:lose
                    content = "message=總分:"+str(score)+"再來一次?  https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116845121018380%26id%3D116833604352865"
                    lose_link = requests.post("https://graph.facebook.com/v13.0/"+level7_comments_id+"/comments?"+content+"&attachment_url=https://i.ibb.co/Ph04ym0/bike-lose.jpg&access_token="+token)
                else:
                    #回覆貼文網址:WIN
                    content = "message=總分:"+str(score)+"WIN!!!!"+"再來一次?  https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116845121018380%26id%3D116833604352865"
                    win_link = requests.post("https://graph.facebook.com/v13.0/"+level7_comments_id+"/comments?"+content+"&attachment_url=https://i.ibb.co/86j3wvD/win.jpg&access_token="+token)
        elif "伊瑟爾" in level7_comments: ##判斷level4有沒有答對
            if "A" in level4_comments or "a" in level4_comments:  #答對直接計算分數
                if score < 10:
                    #回覆貼文網址:lose
                    content = "message=總分:"+str(score)+"再來一次?  https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116845121018380%26id%3D116833604352865"
                    lose_link = requests.post("https://graph.facebook.com/v13.0/"+level7_comments_id+"/comments?"+content+"&attachment_url=https://i.ibb.co/zNw1DyF/excel-lose.jpg&access_token="+token)
                else:
                    #回覆貼文網址:WIN
                    content = "message=總分:"+str(score)+"WIN!!!!"+"再來一次?  https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116845121018380%26id%3D116833604352865"
                    win_link = requests.post("https://graph.facebook.com/v13.0/"+level7_comments_id+"/comments?"+content+"&attachment_url=https://i.ibb.co/86j3wvD/win.jpg&access_token="+token) 
            else:  #答錯補成答對的分數
                score+=2
                if score < 10:
                    #回覆貼文網址:lose
                    content = "message=總分:"+str(score)+"再來一次?  https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116845121018380%26id%3D116833604352865"
                    lose_link = requests.post("https://graph.facebook.com/v13.0/"+level7_comments_id+"/comments?"+content+"&attachment_url=https://i.ibb.co/zNw1DyF/excel-lose.jpg&access_token="+token)
                else:
                    #回覆貼文網址:WIN
                    content = "message=總分:"+str(score)+"WIN!!!!"+"再來一次?  https%3A%2F%2Fwww.facebook.com%2Fpermalink.php%3Fstory_fbid%3D116845121018380%26id%3D116833604352865"
                    win_link = requests.post("https://graph.facebook.com/v13.0/"+level7_comments_id+"/comments?"+content+"&attachment_url=https://i.ibb.co/86j3wvD/win.jpg&access_token="+token) 
        else: #如果沒寫對角色名稱直接GAME OVER
            game_over = requests.post("https://graph.facebook.com/v13.0/"+level7_comments_id+"/comments?message=你說啥?GAME OVER!!!&access_token="+token) 
    return score

def restart(active):
    #是否重開一局
    restart_id = jd["data"][-10]["id"] #重新開始遊戲id
    restart_res = requests.get("https://graph.facebook.com/v13.0/"+restart_id+"/comments?access_token="+token)
    restart_jd=json.loads(restart_res.text)
    if restart_jd["data"]==[]:
        return restart(active)
    else:
        restart_comments = restart_jd["data"][0]["message"] #第一個留言內容
        restart_comments_id = restart_jd["data"][0]["id"] #第一個留言id
        comments_id.append(restart_comments_id)
        if "是" in restart_comments:
            #刪除留言:要留所有留言的id
            for comments in comments_id:
                requests.delete("https://graph.facebook.com/v13.0/"+comments+"?access_token="+token)
                active = False
        else: #不管怎樣都要刪除留言
            for comments in comments_id:
                requests.delete("https://graph.facebook.com/v13.0/"+comments+"?access_token="+token)
                active = False
    return active

###GAME ON!!!!!


active = True     #是否開始玩遊戲及啟動關卡 
ans_total={} #存放角色的答案&得分，例:{"level1":["A",2]}
char_name=["派森","百科","伊瑟爾"]


while active:
    comments_id=[]
    ans_comments=[]
    player_num=game_start()  #玩遊戲的人數=int
    player_name=level_char()  #玩家選擇角色名=[]
    for name in player_name:
        ans_total[name]={}
    for name in player_name: #第一關
        level1()
        ans_total[name]["level1"]=level1()
    for name in player_name: #第二關
        level2()
        ans_total[name]["level2"]=level2()
    print(ans_total)
    #第三關&第四關
    for name in player_name:
        if ans_total[name]["level2"] == 2: #如果level2答對直接去level4
            level4()
            ans_total[name]["level4"] == level4()
        else:   #反之，從level3開始再接level4
            level3()
            ans_total[name]["level3"] == level3()
            level4()
            ans_total[name]["level4"] == level4()
    active=False
#         score=level5(score)
#         score=level6(score)
#         score=level7(score)    
#         active=restart(active)
# Out:
# {'派森': {'level1': 3, 'level2': 0}, '百科': {'level1': 2, 'level2': 2}}

# %%
import numpy as np
x=np.array([[5,6,7],[8,6,5]])
y=np.array([[1,2],[2,4],[6,8]])
z=x.dot(y)
print(z)
# Out:
# [[59 90]
#  [50 80]]

# %%
hh={}
hh["lee"]=5
hh

player_name
# Out:
# []

# %%
a="start+6"
a=a.split("+")
a
if "start" in a:
    print(int(a[1]))
# Out:
# 6

# %%
aa=["asd","ert"]
for bb in aa:
    print(bb)
# Out:
# asd
# ert

# %%
for comments in comments_id:
    requests.delete("https://graph.facebook.com/v13.0/"+comments+"?access_token="+token)

# %%
ans_total={}
for name in player_name:
    ans_total[name]=ans0
print(ans_total[name])
print(name)
# Out:
# {'level1': 3, 'level2': 0}
# 百科
